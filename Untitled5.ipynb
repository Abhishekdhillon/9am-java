# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishekdhillon/9am-java/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# Out:
# /content

# %%
# !wget https://dlcdn.apache.org/spark/spark-3.2.1/spark-3.2.1-bin-hadoop3.2.tgz
# Out:
# --2022-04-13 04:03:29--  https://dlcdn.apache.org/spark/spark-3.2.1/spark-3.2.1-bin-hadoop3.2.tgz
# Resolving dlcdn.apache.org (dlcdn.apache.org)... 151.101.2.132, 2a04:4e42::644
# Connecting to dlcdn.apache.org (dlcdn.apache.org)|151.101.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 300971569 (287M) [application/x-gzip]
# Saving to: ‘spark-3.2.1-bin-hadoop3.2.tgz’
#
# spark-3.2.1-bin-had 100%[===================>] 287.03M   227MB/s    in 1.3s
#
# 2022-04-13 04:03:43 (227 MB/s) - ‘spark-3.2.1-bin-hadoop3.2.tgz’ saved [300971569/300971569]

# %%
# !tar -xvzf spark-3.2.1-bin-hadoop3.2.tgz
# Out:
# spark-3.2.1-bin-hadoop3.2/
# spark-3.2.1-bin-hadoop3.2/LICENSE
# spark-3.2.1-bin-hadoop3.2/NOTICE
# spark-3.2.1-bin-hadoop3.2/R/
# spark-3.2.1-bin-hadoop3.2/R/lib/
# spark-3.2.1-bin-hadoop3.2/R/lib/SparkR/
# spark-3.2.1-bin-hadoop3.2/R/lib/SparkR/DESCRIPTION
# spark-3.2.1-bin-hadoop3.2/R/lib/SparkR/INDEX
# spark-3.2.1-bin-hadoop3.2/R/lib/SparkR/Meta/
# spark-3.2.1-bin-hadoop3.2/R/lib/SparkR/Meta/Rd.rds
# spark-3.2.1-bin-hadoop3.2/R/lib/SparkR/Meta/features.rds
# spark-3.2.1-bin-hadoop3.2/R/lib/SparkR/Meta/hsearch.rds
# spark-3.2.1-bin-hadoop3.2/R/lib/SparkR/Meta/links.rds
# spark-3.2.1-bin-hadoop3.2/R/lib/SparkR/Meta/nsInfo.rds
# spark-3.2.1-bin-hadoop3.2/R/lib/SparkR/Meta/package.rds
# spark-3.2.1-bin-hadoop3.2/R/lib/SparkR/Meta/vignette.rds
# spark-3.2.1-bin-hadoop3.2/R/lib/SparkR/NAMESPACE
# spark-3.2.1-bin-hadoop3.2/R/lib/SparkR/R/
# spark-3.2.1-bin-hadoop3.2/R/lib/SparkR/R/SparkR
# spark-3.2.1-bin-hadoop3.2/R/lib/SparkR/R/SparkR.rdb
# ...

# %%
# !ls /content/spark-3.2.1-bin-hadoop3.2
# Out:
# bin   data	jars	    LICENSE   NOTICE  R		 RELEASE  yarn
# conf  examples	kubernetes  licenses  python  README.md  sbin

# %%
pip install findspark

# %%
pip install pyspark
# Out:
# ...
#      |████████████████████████████████| 281.4 MB 38 kB/s
# ...
#      |████████████████████████████████| 198 kB 64.9 MB/s
# ...
#   Created wheel for pyspark: filename=pyspark-3.2.1-py2.py3-none-any.whl size=281853642 sha256=a9788e868ab384b8d89bb45a12f258f53da3586f950487deb3301990a32ab2d1
#   Stored in directory: /root/.cache/pip/wheels/9f/f5/07/7cd8017084dce4e93e84e92efd1e1d5334db05f2e83bcef74f
# Successfully built pyspark
# ...

# %%
import os
import sys
import findspark
findspark.init()
from pyspark.sql import SparkSession
from pyspark.sql.types import *

# %%
from pyspark.ml.feature import StringIndexer
from pyspark.ml.feature import OneHotEncoder
from pyspark.ml import Pipeline
spark = SparkSession.builder.appName('Exercise13.').getOrCreate()

# %%
#import SparkSession
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('Examplespark').getOrCreate()
from pyspark.sql.types import *
#create the structure of schema
schema = StructType().add("id","integer").add("name","string").add("qualification","string").add("age", "integer").add("gender", "string").add("passed", "integer")
#create data
data = [
    (1,'John',"BSc", 20, "Male", 1),
    (2,'Martha',"MSc", 20, "Female", 1),
    (3,'Mona',"MSc", 21, "Female", 1),
    (4,'Harish',"MScISDF.", 22, "Male", 1),
    (5,'Jonny',"BSc", 22, "Male", 0),
    (6,'Maria',"BSc", 23, "Female", 1),
    (7,'Monalisa',"BSc", 21, "Female", 0)
]
#
#create dataframe
df = spark.createDataFrame(data, schema=schema)
#columns of dataframe
df.columns
df.show()
#import required libraries
from pyspark.ml.feature import StringIndexer
qualification_indexer = StringIndexer(inputCol="qualification", outputCol="qualificationIndex")
#Fits a model to the input dataset with optional parameters.
df = qualification_indexer.fit(df).transform(df)
df.show()
gender_indexer = StringIndexer(inputCol="gender", outputCol="genderIndex")
#Fits a model to the input dataset with optional parameters.
df = gender_indexer.fit(df).transform(df)
df.show()
from pyspark.ml.feature import OneHotEncoder
#onehotencoder to qualificationIndex
onehotencoder_qualification_vector = OneHotEncoder(inputCol="qualificationIndex", outputCol="qualification_vec")
df = onehotencoder_qualification_vector.fit(df).transform(df)
df.show()
#onehotencoder to genderIndex
onehotencoder_gender_vector = OneHotEncoder(inputCol="genderIndex", outputCol="gender_vec")
df = onehotencoder_gender_vector.fit(df).transform(df)
df.show()
from pyspark.ml.feature import VectorAssembler
#dataframe columns 
df.columns
inputCols = [
 'age',
 'qualification_vec',
 'gender_vec'
]
outputCol = "features"
df_va = VectorAssembler(inputCols = inputCols, outputCol = outputCol)
df = df_va.transform(df)
df.select(['features']).toPandas().head(5)
new_df = df.select(['features','passed'])
new_df.show()
#Using PipeLine
#import module
from pyspark.ml import Pipeline
#create the structure of schema
schema = StructType().add("id","integer").add("name","string").add("qualification","string").add("age", "integer").add("gender", "string").add("passed", "integer")

#create data
data = [
     (1,'John',"BSc", 20, "Male", 1),
    (2,'Martha',"MSc.", 20, "Female", 1),
    (3,'Mona',"MSc.", 21, "Female", 1),
    (4,'Harish',"MSc ISDF.", 22, "Male", 1),
    (5,'Jonny',"BSc", 22, "Male", 0),
    (6,'Maria',"BSc", 23, "Female", 1),
    (7,'Monalisa',"BSc", 21, "Female", 0)
]
df = spark.createDataFrame(data, schema=schema)
df.show()
#Create Pipeline and pass all stages
#Convert qualification and gender columns to numeric
qualification_indexer = StringIndexer(inputCol="qualification", outputCol="qualificationIndex")
gender_indexer = StringIndexer(inputCol="gender", outputCol="genderIndex")

#Convert qualificationIndex and genderIndex
onehot_encoder = OneHotEncoder(inputCols=["qualificationIndex", "genderIndex"], outputCols=["qualification_vec", "gender_vec"])

#Merge multiple columns into a vector column
vector_assembler = VectorAssembler(inputCols=['age', 'qualification_vec', 'gender_vec'], outputCol='features')
#Create pipeline and pass it to stages
pipeline = Pipeline(stages=[
           qualification_indexer, 
           gender_indexer,
           onehot_encoder,
           vector_assembler
])
#fit and transform
df_transformed = pipeline.fit(df).transform(df)
df_transformed.show()
#
df_transformed = df_transformed.select(['features','passed'])
df_transformed.show()
#to pandas
df_transformed.toPandas()
# Out:
# +---+--------+-------------+---+------+------+
# | id|    name|qualification|age|gender|passed|
# +---+--------+-------------+---+------+------+
# |  1|    John|          BSc| 20|  Male|     1|
# |  2|  Martha|          MSc| 20|Female|     1|
# |  3|    Mona|          MSc| 21|Female|     1|
# |  4|  Harish|     MScISDF.| 22|  Male|     1|
# |  5|   Jonny|          BSc| 22|  Male|     0|
# |  6|   Maria|          BSc| 23|Female|     1|
# |  7|Monalisa|          BSc| 21|Female|     0|
# +---+--------+-------------+---+------+------+
#
# +---+--------+-------------+---+------+------+------------------+
# | id|    name|qualification|age|gender|passed|qualificationIndex|
# +---+--------+-------------+---+------+------+------------------+
# |  1|    John|          BSc| 20|  Male|     1|               0.0|
# |  2|  Martha|          MSc| 20|Female|     1|               1.0|
# |  3|    Mona|          MSc| 21|Female|     1|               1.0|
# ...

# %%
from pyspark.ml.feature import StringIndexer
from pyspark.ml.feature import OneHotEncoder
spark = SparkSession.builder.appName('Exercise13.').getOrCreate()
from pyspark.sql.types import StructField, StructType, StringType, LongType, IntegerType
schema = StructType().add("id","integer").add("name","string").add("qualification","string").add("age", "integer").add("gender", "string").add("passed", "integer")
#create data
data = [
(1,'John',"BSc", 20, "Male", 1),
(2,'Martha',"MSc", 20, "Female", 0),
(3,'Mona',"MSc", 21, "Female", 0),
(4,'Harish',"MScISDF", 22, "Male", 1),
(5,'Jonny',"BSc", 22, "Male", 1),
(6,'Maria',"BSc", 23, "Female", 1),
(7,'Monalisa',"BSc", 21, "Female", 1)
]
#create dataframe
df = spark.createDataFrame(data, schema=schema)
#columns of dataframe
df.columns
df.show()
from pyspark.ml.feature import StringIndexer
qualification_indexer = StringIndexer(inputCol="qualification", outputCol="qualificationIndex")
#Fits a model to the input dataset with optional parameters.
df = qualification_indexer.fit(df).transform(df)
df.show()
gender_indexer = StringIndexer(inputCol="gender", outputCol="genderIndex")
#Fits a model to the input dataset with optional parameters.
df = gender_indexer.fit(df).transform(df)
df.show()
onehotencoder_qualification_vector = OneHotEncoder(inputCol="qualificationIndex", outputCol="qualification_vec")
df = onehotencoder_qualification_vector.fit(df).transform(df)
df.show()
onehotencoder_gender_vector = OneHotEncoder(inputCol="genderIndex", outputCol="gender_vec")
df = onehotencoder_gender_vector.fit(df).transform(df)
df.show()
from pyspark.ml.feature import VectorAssembler
df.columns
inputCols = ['age', 'qualification_vec', 'gender_vec']
outputCol = "features"
df_va = VectorAssembler(inputCols = inputCols, outputCol = outputCol)
df = df_va.transform(df)
df.select(['features']).toPandas().head(5)
new_df = df.select(['features','passed'])
new_df.show()
#Create Pipeline and pass all stages
#Convert qualification and gender columns to numeric
import pyspark 
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('example1').getOrCreate()
from pyspark.sql.types import StructField, StructType, StringType, LongType,IntegerType

schema = StructType([
    StructField("id", IntegerType(), True),
    StructField("name", StringType(), True),
    StructField("qualification", StringType()),
    StructField("age", IntegerType()),
    StructField("gender", StringType()),
    StructField("passed", IntegerType()),
                ])

data = [(1,"John","BSC",20,"Male",1),
       (2,"Martha","MSC.",20,"Female",1),
       (3,"Mona","msc.",21,"Female",1),
       (4,'Harish',"MSc ISDF.", 22, "Male", 1),
       (5,'Jonny',"BSc", 22, "Male", 0),
(6,'Maria',"BSc", 23, "Female", 1),
(7,'Monalisa',"BSc", 21, "Female", 0)]

df = spark.createDataFrame(data, schema=schema)

from pyspark.ml.feature import StringIndexer,OneHotEncoder,VectorAssembler

qualification_indexer = StringIndexer(inputCol="qualification", outputCol="qualificationIndex")

qualification_indexer = StringIndexer(inputCol="qualification", outputCol="qualificationIndex")
gender_indexer = StringIndexer(inputCol="gender", outputCol="genderIndex")

#Convert qualificationIndex and genderIndex
df = spark.createDataFrame(data, schema = schema)
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler
onehot_encoder1 = OneHotEncoder(inputCol="qualificationIndex", outputCol="qualification_vec")
onehot_encoder2 = OneHotEncoder(inputCol=["genderIndex"], outputCol=["gender_vec"])

#Merge multiple columns into a vector column
vector_assembler = VectorAssembler(inputCols=['age', 'qualification_vec', 'gender_vec'], outputCol='features')
#Create pipeline and pass it to stages
from pyspark.ml import Pipeline
pipeline = Pipeline(stages=[qualification_indexer, gender_indexer, onehot_encoder, vector_assembler])
#fit and transform
df_transformed = pipeline.fit(df).transform(df)
df_transformed.show()

df_transformed = df_transformed.select(['features','passed'])
df_transformed.show()
# Out:
# +---+--------+-------------+---+------+------+
# | id|    name|qualification|age|gender|passed|
# +---+--------+-------------+---+------+------+
# |  1|    John|          BSc| 20|  Male|     1|
# |  2|  Martha|          MSc| 20|Female|     0|
# |  3|    Mona|          MSc| 21|Female|     0|
# |  4|  Harish|      MScISDF| 22|  Male|     1|
# |  5|   Jonny|          BSc| 22|  Male|     1|
# |  6|   Maria|          BSc| 23|Female|     1|
# |  7|Monalisa|          BSc| 21|Female|     1|
# +---+--------+-------------+---+------+------+
#
# +---+--------+-------------+---+------+------+------------------+
# | id|    name|qualification|age|gender|passed|qualificationIndex|
# +---+--------+-------------+---+------+------+------------------+
# |  1|    John|          BSc| 20|  Male|     1|               0.0|
# |  2|  Martha|          MSc| 20|Female|     0|               1.0|
# |  3|    Mona|          MSc| 21|Female|     0|               1.0|
# ...

# %%
import pyspark 
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('example1').getOrCreate()
from pyspark.sql.types import StructField, StructType, StringType, LongType,IntegerType

schema = StructType([
    StructField("id", IntegerType(), True),
    StructField("name", StringType(), True),
    StructField("qualification", StringType()),
    StructField("age", IntegerType()),
    StructField("gender", StringType()),
    StructField("passed", IntegerType()),
                ])

data = [(1,"John","BSC",20,"Male",1),
       (2,"Martha","MSC.",20,"Female",1),
       (3,"Mona","msc.",21,"Female",1),
       (4,'Harish',"MSc ISDF.", 22, "Male", 1),
       (5,'Jonny',"BSc", 22, "Male", 0),
(6,'Maria',"BSc", 23, "Female", 1),
(7,'Monalisa',"BSc", 21, "Female", 0)]

df = spark.createDataFrame(data, schema=schema)

from pyspark.ml.feature import StringIndexer,OneHotEncoder,VectorAssembler

qualification_indexer = StringIndexer(inputCol="qualification", outputCol="qualificationIndex")
gender_indexer = StringIndexer(inputCol="gender", outputCol="genderIndex")
#Convert qualificationIndex and genderIndex
onehot_encoder1 = OneHotEncoder(inputCol="qualificationIndex", 
 outputCol="qualification_vec")
onehot_encoder2 = OneHotEncoder(inputCol="genderIndex", 
 outputCol="gender_vec")
vector_assembler = VectorAssembler(inputCols=['age', 'qualification_vec', 'gender_vec'], outputCol='features')
from pyspark.ml import Pipeline
pipeline = Pipeline(stages=[qualification_indexer,gender_indexer,
                            onehot_encoder1,onehot_encoder2,vector_assembler
])

df_transformed = pipeline.fit(df).transform(df)

df_transformed.show()
# Out:
# +---+--------+-------------+---+------+------+------------------+-----------+-----------------+-------------+--------------------+
# | id|    name|qualification|age|gender|passed|qualificationIndex|genderIndex|qualification_vec|   gender_vec|            features|
# +---+--------+-------------+---+------+------+------------------+-----------+-----------------+-------------+--------------------+
# |  1|    John|          BSC| 20|  Male|     1|               1.0|        1.0|    (4,[1],[1.0])|    (1,[],[])|(6,[0,2],[20.0,1.0])|
# |  2|  Martha|         MSC.| 20|Female|     1|               2.0|        0.0|    (4,[2],[1.0])|(1,[0],[1.0])|[20.0,0.0,0.0,1.0...|
# |  3|    Mona|         msc.| 21|Female|     1|               4.0|        0.0|        (4,[],[])|(1,[0],[1.0])|(6,[0,5],[21.0,1.0])|
# |  4|  Harish|    MSc ISDF.| 22|  Male|     1|               3.0|        1.0|    (4,[3],[1.0])|    (1,[],[])|(6,[0,4],[22.0,1.0])|
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame({"Name":['Jai', 'abhi', 'ayani'], "Department":[1,2,3]})
df.head()
df.boxplot(column="Department")

# %%
years = [2021,2022,2023,2024]
totalGraduates= [100,4000,1380,1786]
plt.plot(years,totalGraduates, color ='red',linestyle='--')
plt.xlabel('Year')
plt.ylabel('TotalGraduates')
plt.title('Graduates of LSBF(2021-2024)')
plt.xticks(years)
# Out:
# ([<matplotlib.axis.XTick at 0x7f14db6f11d0>,
# ...
#  <a list of 4 Text major ticklabel objects>)

# %%
grades=['D', 'C', 'P', 'F']
totalNumStudents=[5,10,15,0]
list_colors=['green', 'red', 'purple', 'blue']
bars =plt.bar(grades, totalNumStudents, color =list_colors, edgecolor='black')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as SparkSession
census_data=pd.read_csv('https://raw.githubusercontent.com/thems18/Data-Visualization/master/Seaborn/census_data.csv')
census_data.head()
# Out:
#    age          workclass   education  education_num       marital_status  \
# 0   39          State-gov   Bachelors             13        Never-married
# 1   50   Self-emp-not-inc   Bachelors             13   Married-civ-spouse
# 2   38            Private     HS-grad              9             Divorced
# 3   53            Private        11th              7   Married-civ-spouse
# 4   28            Private   Bachelors             13   Married-civ-spouse
#
#            occupation    relationship    race   gender  capital_gain  \
# 0        Adm-clerical   Not-in-family   White     Male          2174
# 1     Exec-managerial         Husband   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Husband   Black     Male             0
# 4      Prof-specialty            Wife   Black   Female             0
#
#    capital_loss  hours_per_week  native_country income_bracket
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
correlation_analysis= census_data.corr()
sns.heatmap(correlation_analysis, annot=True)

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x= 'capital_loss', y= 'capital_gain', hue= 'marital_status', data = census_data)
plt.figure(figsize=(10,8))
sns.scatterplot(x= 'capital_loss', y= 'capital_gain', hue= 'marital_status', size= 'age', sizes= (10,200), data = census_data)
sns.lineplot(x= 'age', y= 'hours_per_week', data=census_data, ci=None)

# %%
sns.lineplot(x= 'age', y= 'hours_per_week', data=census_data, ci=None)

# %%
sns.lineplot(x= 'age', y= 'hours_per_week', hue= 'gender', data=census_data, ci=None)

# %%
sns.relplot(x= 'capital_loss', y= 'capital_gain', hue= 'marital_status', size= 'age', col= 'income_bracket', sizes= (10,100), data= census_data)

# %%
sns.relplot(x= 'age', y= 'hours_per_week', kind='line', col= 'income_bracket', hue= 'gender', data=census_data, ci=None)

# %%
sns.relplot(x= 'age', y= 'hours_per_week', kind='line', row= 'race', col= 'income_bracket', hue= 'gender', data=census_data, ci=None)

# %%
sns.relplot(x= 'age', y= 'hours_per_week', kind='scatter', row= 'race', col= 'income_bracket', hue= 'gender', data=census_data, ci=None)

# %%
fig=plt.figure(figsize=(20,15))
plt.subplot(2,2,1)

# %%
fig= plt.figure(figsize= (20,15))
plt.subplot(2,2,1)
sns.scatterplot(x= 'capital_loss', y= 'capital_gain', hue= 'marital_status', data= census_data)
plt.subplot(2,2,2)
sns.relplot(x= 'age', y= 'hours_per_week', hue= 'gender', data=census_data, ci=None)
plt.subplot(2,2,3)
bars = plt.bar(grades,totalNumStudents, color=list_colors, edgecolor='black')
plt.show()
